# %% [markdown]
# # Web scraping pour collecter des données sur les films

# %%
#Installation bs4
pip install bs4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import librairies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Test de la méthode : Récupération des données à partir d'un url

# %%
#Lien vers le classement de la première partie des films (50 premiers)
url = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating"

# %%
#Récupérer les titres des films en anglais 
headers = {"Accept-Language": "en-US,en;q=0.5"}
page = requests.get(url, headers=headers)
page
# Out:
# <Response [200]>

# %%
## display the page source code
page.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb &quot;Top 250&quot;\n(Sorted by IMDb Rating Descending) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n 
# ...

# %%
soup = BeautifulSoup(page.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    IMDb "Top 250"
# (Sorted by IMDb Rating Descending) - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# ...

# %%
# scrapped movie names
scraped_movies =soup.find_all("h3", class_="lister-item-header")
scraped_movies
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt0068646/">The Godfather</a>
#  <span class="lister-item-year text-muted unbold">(1972)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0468569/">The Dark Knight</a>
#  <span class="lister-item-year text-muted unbold">(2008)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0071562/">The Godfather: Part II</a>
#  <span class="lister-item-year text-muted unbold">(1974)</span>
#  </h3>,
#  <h3 class="lister-item-header">
# ...

# %%
# parse movie names
movies = []
for movie in scraped_movies:
    movie = movie.get_text().replace('\n', "")
    movie = movie.strip(" ")
    movies.append(movie)
movies
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Dark Knight(2008)',
#  '4.The Godfather: Part II(1974)',
#  '5.12 Angry Men(1957)',
#  '6.The Lord of the Rings: The Return of the King(2003)',
#  '7.Pulp Fiction(1994)',
#  "8.Schindler's List(1993)",
#  '9.Inception(2010)',
#  '10.Fight Club(1999)',
#  '11.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '12.Forrest Gump(1994)',
#  '13.The Good, the Bad and the Ugly(1966)',
#  '14.The Lord of the Rings: The Two Towers(2002)',
#  '15.The Matrix(1999)',
#  '16.Goodfellas(1990)',
#  '17.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Parasite(2019)',
#  '20.Interstellar(2014)',
#  '21.City of God(2002)',
#  '22.Spirited Away(2001)',
#  '23.Saving Private Ryan(1998)',
#  '24.The Green Mile(1999)',
#  '25.Life Is Beautiful(1997)',
#  '26.Se7en(1995)',
#  '27.The Silence of the Lambs(1991)',
#  '28.Star Wars: Episode IV - A New Hope(1977)',
# ...

# %%
# scrapped movie date
scraped_movies =soup.find_all("span", class_="lister-item-year text-muted unbold")
scraped_movies
# Out:
# [<span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1972)</span>,
#  <span class="lister-item-year text-muted unbold">(2008)</span>,
#  <span class="lister-item-year text-muted unbold">(1974)</span>,
#  <span class="lister-item-year text-muted unbold">(1957)</span>,
#  <span class="lister-item-year text-muted unbold">(2003)</span>,
#  <span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1993)</span>,
#  <span class="lister-item-year text-muted unbold">(2010)</span>,
#  <span class="lister-item-year text-muted unbold">(1999)</span>,
#  <span class="lister-item-year text-muted unbold">(2001)</span>,
#  <span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1966)</span>,
#  <span class="lister-item-year text-muted unbold">(2002)</span>,
# ...

# %%
# parse movie dates
dates = []
for date in scraped_movies:
    date = date.get_text().replace('\n', "")
    date = date.strip(" ")
    dates.append(date)
dates
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(2003)',
#  '(1994)',
#  '(1993)',
#  '(2010)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2002)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2019)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1991)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1968)',
#  '(1960)',
#  '(1955)',
#  '(1954)',
#  '(1942)']

# %%
# scrapped movie date
scraped_movies =soup.find_all("span", class_="genre")
scraped_movies
# Out:
# [<span class="genre">
#  Drama            </span>,
#  <span class="genre">
#  Crime, Drama            </span>,
#  <span class="genre">
#  Action, Crime, Drama            </span>,
#  <span class="genre">
#  Crime, Drama            </span>,
#  <span class="genre">
#  Crime, Drama            </span>,
#  <span class="genre">
#  Action, Adventure, Drama            </span>,
#  <span class="genre">
#  Crime, Drama            </span>,
#  <span class="genre">
#  Biography, Drama, History            </span>,
#  <span class="genre">
#  Action, Adventure, Sci-Fi            </span>,
#  <span class="genre">
#  Drama            </span>,
#  <span class="genre">
#  Action, Adventure, Drama            </span>,
#  <span class="genre">
#  Drama, Romance            </span>,
#  <span class="genre">
#  Western            </span>,
#  <span class="genre">
#  Action, Adventure, Drama            </span>,
#  <span class="genre">
#  Action, Sci-Fi            </span>,
#  <span class="genre">
# ...

# %%
# parse movie dates
genres = []
for genre in scraped_movies:
    genre = genre.get_text().replace('\n', "")
    genre = genre.strip(" ")
    genres.append(genre)
genres
# Out:
# ['Drama',
#  'Crime, Drama',
#  'Action, Crime, Drama',
#  'Crime, Drama',
#  'Crime, Drama',
#  'Action, Adventure, Drama',
#  'Crime, Drama',
#  'Biography, Drama, History',
#  'Action, Adventure, Sci-Fi',
#  'Drama',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
#  'Western',
#  'Action, Adventure, Drama',
#  'Action, Sci-Fi',
#  'Biography, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Drama',
#  'Comedy, Drama, Thriller',
#  'Adventure, Drama, Sci-Fi',
#  'Crime, Drama',
#  'Animation, Adventure, Family',
#  'Drama, War',
#  'Crime, Drama, Fantasy',
#  'Comedy, Drama, Romance',
#  'Crime, Drama, Mystery',
#  'Crime, Drama, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Family, Fantasy',
#  'Drama, Music',
#  'Biography, Comedy, Drama',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Biography, Drama, Music',
#  'Action, Adventure, Drama',
#  'Drama',
#  'Crime, Drama, Mystery',
# ...

# %%
# scrapped movie date
scraped_movies =soup.find_all("span", class_="runtime")
scraped_movies
# Out:
# [<span class="runtime">142 min</span>,
#  <span class="runtime">175 min</span>,
#  <span class="runtime">152 min</span>,
#  <span class="runtime">202 min</span>,
#  <span class="runtime">96 min</span>,
#  <span class="runtime">201 min</span>,
#  <span class="runtime">154 min</span>,
#  <span class="runtime">195 min</span>,
#  <span class="runtime">148 min</span>,
#  <span class="runtime">139 min</span>,
#  <span class="runtime">178 min</span>,
#  <span class="runtime">142 min</span>,
#  <span class="runtime">178 min</span>,
#  <span class="runtime">179 min</span>,
#  <span class="runtime">136 min</span>,
#  <span class="runtime">146 min</span>,
#  <span class="runtime">124 min</span>,
#  <span class="runtime">133 min</span>,
#  <span class="runtime">132 min</span>,
#  <span class="runtime">169 min</span>,
#  <span class="runtime">130 min</span>,
#  <span class="runtime">125 min</span>,
#  <span class="runtime">169 min</span>,
#  <span class="runtime">189 min</span>,
# ...

# %%
# parse movie dates
times = []
for time in scraped_movies:
    time = time.get_text().replace('\n', "")
    time = time.strip(" ")
    times.append(time)
times
# Out:
# ['142 min',
#  '175 min',
#  '152 min',
#  '202 min',
#  '96 min',
#  '201 min',
#  '154 min',
#  '195 min',
#  '148 min',
#  '139 min',
#  '178 min',
#  '142 min',
#  '178 min',
#  '179 min',
#  '136 min',
#  '146 min',
#  '124 min',
#  '133 min',
#  '132 min',
#  '169 min',
#  '130 min',
#  '125 min',
#  '169 min',
#  '189 min',
#  '116 min',
#  '127 min',
#  '118 min',
#  '121 min',
#  '133 min',
#  '207 min',
#  '130 min',
#  '106 min',
#  '112 min',
#  '130 min',
#  '151 min',
#  '150 min',
#  '155 min',
#  '119 min',
#  '106 min',
#  '110 min',
#  '88 min',
#  '137 min',
#  '155 min',
#  '89 min',
#  '116 min',
#  '165 min',
#  '109 min',
#  '125 min',
#  '112 min',
#  '102 min']

# %%
# scrapped movie rating
scraped_movies =soup.find_all("div", class_="inline-block ratings-imdb-rating")
scraped_movies
# Out:
# [<div class="inline-block ratings-imdb-rating" data-value="9.3" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.3</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9.2" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.2</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="8.9" name="ir">
# ...

# %%
# parse movie dates
scores = []
for score in scraped_movies:
    score  = score .get_text().replace('\n', "")
    score = score .strip(" ")
    scores.append(score)
scores
# Out:
# ['9.3',
#  '9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5']

# %%
data = pd.DataFrame()

data['Movie Names']= movies
data['Ratings']= scores
data['Genres']= genres
data['Date de sortie']= dates 

data
# Out:
#                                           Movie Names Ratings  \
# 0                    1.The Shawshank Redemption(1994)     9.3
# 1                               2.The Godfather(1972)     9.2
# 2                             3.The Dark Knight(2008)     9.0
# 3                      4.The Godfather: Part II(1974)     9.0
# 4                                5.12 Angry Men(1957)     9.0
# 5   6.The Lord of the Rings: The Return of the Kin...     8.9
# 6                                7.Pulp Fiction(1994)     8.9
# 7                            8.Schindler's List(1993)     8.9
# 8                                   9.Inception(2010)     8.8
# 9                                 10.Fight Club(1999)     8.8
# 10  11.The Lord of the Rings: The Fellowship of th...     8.8
# 11                              12.Forrest Gump(1994)     8.8
# 12            13.The Good, the Bad and the Ugly(1966)     8.8
# 13     14.The Lord of the Rings: The Two Towers(2002)     8.7
# ...

# %%
#La métode a bien fonctionné, on récupère les 50 premiers films (présent sur la page de l'URL que nous avons entré)
#Il faut généraliser la méthode utilisée pour récupérer les 250 films avec 5 url différents 
#On doit faire une boucle

# %% [markdown]
# # 1ère partie du TP: Récupérer la première partie de l'information (titre, genre, date, durée) du site IMDb

# %%
#Création d'une liste des 5 URLs
url = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating"

url_2 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt"

url_3 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt"

url_4 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt"

url_5 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt"

urls=[url, url_2, url_3, url_4, url_5]

# %%
movies_data=[]

headers = {"Accept-Language": "en-US,en;q=0.5"}

# Boucler sur les urls définies plus haut
for url in urls:
    # récupérer le html de la page
    data = requests.get(url, headers=headers)
    
    # ajouter les données de la page html à BeautifulSoup
    soup =  BeautifulSoup(data.text, 'html.parser')
    
    # Boucler sur chaque div contenant les infos nécessaires (classe de la div = 'lister-item-content')
    for div in soup.find_all('div', { 'class' : 'lister-item-content' }):
        # Récupérer le titre et retirer les balises html
        title = div.find('a')
        title_text = title.text
        # Récupérer l'année et retirer les balises html
        year = div.find("span", class_="lister-item-year").text
        # Récupérer la durée et retirer les balises html
        runtime = div.find('span', {'class':'runtime'}).text
        # Récupérer le genre et retirer les balises html
        genre = div.find('span', {'class':'genre'}).text.strip()

        # ajouter les 4 éléments de chaque films dans une liste
        data_list = [title_text, year, runtime, genre]
        # ajouter tous les éléments des 50 films dans une liste
        movies_data.append(data_list)

# %%
movies_data
# Out:
# [['The Shawshank Redemption', '(1994)', '142 min', 'Drama'],
#  ['The Godfather', '(1972)', '175 min', 'Crime, Drama'],
#  ['The Dark Knight', '(2008)', '152 min', 'Action, Crime, Drama'],
#  ['The Godfather: Part II', '(1974)', '202 min', 'Crime, Drama'],
#  ['12 Angry Men', '(1957)', '96 min', 'Crime, Drama'],
#  ['The Lord of the Rings: The Return of the King',
#   '(2003)',
#   '201 min',
#   'Action, Adventure, Drama'],
#  ['Pulp Fiction', '(1994)', '154 min', 'Crime, Drama'],
#  ["Schindler's List", '(1993)', '195 min', 'Biography, Drama, History'],
#  ['Inception', '(2010)', '148 min', 'Action, Adventure, Sci-Fi'],
#  ['Fight Club', '(1999)', '139 min', 'Drama'],
#  ['The Lord of the Rings: The Fellowship of the Ring',
#   '(2001)',
#   '178 min',
#   'Action, Adventure, Drama'],
#  ['Forrest Gump', '(1994)', '142 min', 'Drama, Romance'],
#  ['The Good, the Bad and the Ugly', '(1966)', '178 min', 'Western'],
#  ['The Lord of the Rings: The Two Towers',
#   '(2002)',
# ...

# %%
data2 = pd.DataFrame(movies_data, columns = ['title', 'year_of_release', 'duration_in_minutes', 'genre'])

data2
# Out:
#                             title year_of_release duration_in_minutes  \
# 0        The Shawshank Redemption          (1994)             142 min
# 1                   The Godfather          (1972)             175 min
# 2                 The Dark Knight          (2008)             152 min
# 3          The Godfather: Part II          (1974)             202 min
# 4                    12 Angry Men          (1957)              96 min
# ..                            ...             ...                 ...
# 245  Mr. Smith Goes to Washington          (1939)             129 min
# 246            Gone with the Wind          (1939)             238 min
# 247         It Happened One Night          (1934)             105 min
# 248    The Passion of Joan of Arc          (1928)             114 min
# 249                   The General          (1926)              67 min
#
#                          genre
# 0                        Drama
# 1                 Crime, Drama
# ...

# %%
#On répure donc un DF avec les informations necessaires pour chaque films des top 250

# %% [markdown]
# ## Modifications pour préparer la deuxieme partie de l'éxercice

# %%
#Supression des parenthèse autour de la date & et du mot "min" + conversion en int
data2["duration_in_minutes"] = data2["duration_in_minutes"].str[:3].astype(int)
data2["year_of_release"] = data2["year_of_release"].str[1:5]

# %%
data2
# Out:
#                             title year_of_release  duration_in_minutes  \
# 0        The Shawshank Redemption            1994                  142
# 1                   The Godfather            1972                  175
# 2                 The Dark Knight            2008                  152
# 3          The Godfather: Part II            1974                  202
# 4                    12 Angry Men            1957                   96
# ..                            ...             ...                  ...
# 245  Mr. Smith Goes to Washington            1939                  129
# 246            Gone with the Wind            1939                  238
# 247         It Happened One Night            1934                  105
# 248    The Passion of Joan of Arc            1928                  114
# 249                   The General            1926                   67
#
#                          genre
# 0                        Drama
# 1                 Crime, Drama
# ...

# %%
#Remplacer l'espace par un _, pour s'adapter au site rottentomato 
data2.title = data2.title.apply(lambda x:x.replace(" ", "_"))

# %%
data2
# Out:
#                             title year_of_release  duration_in_minutes  \
# 0        The_Shawshank_Redemption            1994                  142
# 1                   The_Godfather            1972                  175
# 2                 The_Dark_Knight            2008                  152
# 3          The_Godfather:_Part_II            1974                  202
# 4                    12_Angry_Men            1957                   96
# ..                            ...             ...                  ...
# 245  Mr._Smith_Goes_to_Washington            1939                  129
# 246            Gone_with_the_Wind            1939                  238
# 247         It_Happened_One_Night            1934                  105
# 248    The_Passion_of_Joan_of_Arc            1928                  114
# 249                   The_General            1926                   67
#
#                          genre
# 0                        Drama
# 1                 Crime, Drama
# ...

# %%
#Enlever le déterminant "the" des titres de films, pour s'adapter au site rottentomato 
data2.title = data2.title.apply(lambda x:x.replace("The_", ""))

# %%
data2
# Out:
#                             title year_of_release  duration_in_minutes  \
# 0            Shawshank_Redemption            1994                  142
# 1                       Godfather            1972                  175
# 2                     Dark_Knight            2008                  152
# 3              Godfather:_Part_II            1974                  202
# 4                    12_Angry_Men            1957                   96
# ..                            ...             ...                  ...
# 245  Mr._Smith_Goes_to_Washington            1939                  129
# 246            Gone_with_the_Wind            1939                  238
# 247         It_Happened_One_Night            1934                  105
# 248        Passion_of_Joan_of_Arc            1928                  114
# 249                       General            1926                   67
#
#                          genre
# 0                        Drama
# 1                 Crime, Drama
# ...

# %% [markdown]
# # 2ème partie de l'exercice, récupérer les deux scores "pop_score" et "tomato_score" à partir de rottentomatoes

# %%
#Création d'une liste avec l'ensemble des liens potentiels pour chaque film des 250 
uri = 'https://www.rottentomatoes.com/m/'
urilist = []
for i in data2["title"]:
    response = (f'{uri}{str(i)}')  
    urilist.append(response)

# %%
urilist
# Out:
# ['https://www.rottentomatoes.com/m/Shawshank_Redemption',
#  'https://www.rottentomatoes.com/m/Godfather',
#  'https://www.rottentomatoes.com/m/Dark_Knight',
#  'https://www.rottentomatoes.com/m/Godfather:_Part_II',
#  'https://www.rottentomatoes.com/m/12_Angry_Men',
#  'https://www.rottentomatoes.com/m/Lord_of_the_Rings:_Return_of_the_King',
#  'https://www.rottentomatoes.com/m/Pulp_Fiction',
#  "https://www.rottentomatoes.com/m/Schindler's_List",
#  'https://www.rottentomatoes.com/m/Inception',
#  'https://www.rottentomatoes.com/m/Fight_Club',
#  'https://www.rottentomatoes.com/m/Lord_of_the_Rings:_Fellowship_of_the_Ring',
#  'https://www.rottentomatoes.com/m/Forrest_Gump',
#  'https://www.rottentomatoes.com/m/Good,_the_Bad_and_the_Ugly',
#  'https://www.rottentomatoes.com/m/Lord_of_the_Rings:_Two_Towers',
#  'https://www.rottentomatoes.com/m/Matrix',
#  'https://www.rottentomatoes.com/m/Goodfellas',
#  'https://www.rottentomatoes.com/m/Star_Wars:_Episode_V_-_Empire_Strikes_Back',
# ...

# %% [markdown]
# # Test

# %%
# pag = requests.get("https://www.rottentomatoes.com/m/elephant_man")
# pag
# Out:
# <Response [200]>

# %%
#soup1 = pag.text

# %%
# soup1 = BeautifulSoup(pag.content, "html.parser")
# print(soup1)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>
# <!-- salt=lay-def-02-juRm -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>The Elephant Man - Rotten Tomatoes</title>
# ...

# %%
# soup1.find("span", class_='percentage')

# %%
# soup1.find("score-board")
# Out:
# <score-board audiencescore="86" audiencestate="upright" class="scoreboard" data-qa="score-panel" rating="" skeleton="panel" tomatometerscore="" tomatometerstate="">
# <h1 class="scoreboard__title" data-qa="score-panel-movie-title" slot="title">The Elephant Man</h1>
# <p class="scoreboard__info" slot="info">1982, Drama/Biography, 1h 37m</p>
# <a class="scoreboard__link scoreboard__link--tomatometer" data-qa="tomatometer-review-count" href="/m/elephant_man/reviews?intcmp=rt-scorecard_tomatometer-reviews" slot="critics-count">0 Reviews</a>
# <a class="scoreboard__link scoreboard__link--audience" data-qa="audience-rating-count" href="/m/elephant_man/reviews?type=user&amp;intcmp=rt-scorecard_audience-score-reviews" slot="audience-count">Fewer than 50 Ratings</a>
# <div id="tomatometer_sponsorship_ad" slot="sponsorship"></div>
# </score-board>

# %%
soup1.find("score-board")["audiencescore"]
# Out:
# '86'

# %%
soup1.find("score-board")["tomatometerscore"]
# Out:
# ''

# %%
#Récupération des scores d'audience pour chaque film

# %%
scores_data=[]

# Boucler sur les urls définies plus haut
for url in urilist:
    # récupérer le html de la page
    pag = requests.get(url)
    
    if pag.status_code == 200:
            
    # ajouter les données de la page html à BeautifulSoup   
        soup1 = BeautifulSoup(pag.content, "html.parser")
   
        audience = soup1.find("score-board")["audiencescore"]
    
        scores_data.append(audience)
        
    else: 
        audience = "Not found"
        
        scores_data.append(audience)

    
scores_data
# Out:
# ['98',
#  '98',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '96',
#  'Not found',
#  '91',
#  '96',
#  'Not found',
#  '95',
#  'Not found',
#  'Not found',
#  '85',
#  '97',
#  'Not found',
#  'Not found',
#  '',
#  '86',
#  '97',
#  '96',
#  '95',
#  '94',
#  'Not found',
#  'Not found',
#  '95',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '93',
#  '92',
#  '94',
#  '96',
#  '87',
#  '96',
#  '96',
#  'Not found',
#  '93',
#  'Not found',
#  '97',
#  '95',
#  '94',
#  '95',
#  '95',
#  '94',
#  '95',
#  'Not found',
#  '95',
#  '96',
#  'Not found',
#  '93',
#  '',
#  'Not found',
#  '94',
#  'Not found',
#  'Not found',
#  'Not found',
#  '',
#  '91',
#  'Not found',
#  '93',
#  '96',
#  'Not found',
#  'Not found',
#  '94',
#  '94',
#  'Not found',
#  '96',
#  '93',
#  '94',
#  '94',
#  '95',
#  'Not found',
#  '95',
#  '95',
#  'Not found',
#  '95',
#  'Not found',
#  '20',
#  'Not found',
#  '92',
#  '',
#  '88',
# ...

# %%
#Convertion en Df
df_scores_pop = pd.DataFrame(scores_data, columns=['pop_score'])
df_scores_pop
# Out:
#      pop_score
# 0           98
# 1           98
# 2    Not found
# 3    Not found
# 4    Not found
# ..         ...
# 245  Not found
# 246         92
# 247         93
# 248         93
# 249  Not found
#
# [250 rows x 1 columns]

# %%
df_scores_pop["pop_score"].value_counts()
# Out:
# Not found    82
# 93           35
# 94           30
# 95           24
# 92           13
#              12
# 96           12
# 90            9
# 91            8
# 86            5
# 97            4
# 89            4
# 98            3
# 87            2
# 20            1
# 42            1
# 85            1
# 36            1
# 39            1
# 88            1
# 75            1
# Name: pop_score, dtype: int64

# %%
#On remarque que 82 liens n'ont pas pu être ouvert, c'est les not found.

# %%
#Récupération des score tomato
tomato_data=[]

# Boucler sur les urls définies plus haut
for url in urilist:
    # récupérer le html de la page
    pag = requests.get(url)
    
    if pag.status_code == 200:
            
    # ajouter les données de la page html à BeautifulSoup   
        soup1 = BeautifulSoup(pag.content, "html.parser")
   
        audience = soup1.find("score-board")["tomatometerscore"]
    
        tomato_data.append(audience)
        
    else: 
        audience = "Not found"
        
        tomato_data.append(audience)

    
tomato_data
# Out:
# ['91',
#  '97',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '92',
#  'Not found',
#  '87',
#  '79',
#  'Not found',
#  '71',
#  'Not found',
#  'Not found',
#  '88',
#  '96',
#  'Not found',
#  'Not found',
#  '',
#  '72',
#  '91',
#  '97',
#  '93',
#  '78',
#  'Not found',
#  'Not found',
#  '96',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '75',
#  '76',
#  '90',
#  '95',
#  '77',
#  '83',
#  '88',
#  'Not found',
#  '93',
#  'Not found',
#  '90',
#  '100',
#  '96',
#  '95',
#  '96',
#  '97',
#  '98',
#  'Not found',
#  '98',
#  '98',
#  'Not found',
#  '90',
#  '',
#  'Not found',
#  '88',
#  'Not found',
#  'Not found',
#  'Not found',
#  '',
#  '87',
#  'Not found',
#  '100',
#  '91',
#  'Not found',
#  'Not found',
#  '81',
#  '93',
#  'Not found',
#  '95',
#  '84',
#  '98',
#  '98',
#  '95',
#  'Not found',
#  '100',
#  '95',
#  'Not found',
#  '93',
#  'Not found',
#  '',
#  'Not found',
#  '92',
#  '',
#  '89',
# ...

# %%
df_scores_tomato = pd.DataFrame(tomato_data, columns=['tomato_score'])
df_scores_tomato
# Out:
#     tomato_score
# 0             91
# 1             97
# 2      Not found
# 3      Not found
# 4      Not found
# ..           ...
# 245    Not found
# 246           90
# 247           99
# 248           98
# 249    Not found
#
# [250 rows x 1 columns]

# %%
df_scores_tomato['tomato_score'].value_counts()
# Out:
# Not found    82
#              16
# 98           15
# 94           14
# 100          13
# 92           11
# 95           10
# 96            9
# 99            8
# 91            8
# 93            8
# 90            7
# 97            7
# 87            6
# 88            5
# 83            4
# 89            3
# 84            3
# 79            2
# 73            2
# 77            2
# 86            2
# 74            2
# 81            2
# 72            1
# 78            1
# 39            1
# 34            1
# 82            1
# 76            1
# 71            1
# 85            1
# 75            1
# Name: tomato_score, dtype: int64

# %%
df_inner = data2.merge(df_scores_tomato, how='inner', left_index=True, right_index=True)

# %%
df_to = df_inner.merge(df_scores_pop, how='inner', left_index=True, right_index=True)

# %%
df_to
# Out:
#                             title year_of_release  duration_in_minutes  \
# 0            Shawshank_Redemption            1994                  142
# 1                       Godfather            1972                  175
# 2                     Dark_Knight            2008                  152
# 3              Godfather:_Part_II            1974                  202
# 4                    12_Angry_Men            1957                   96
# ..                            ...             ...                  ...
# 245  Mr._Smith_Goes_to_Washington            1939                  129
# 246            Gone_with_the_Wind            1939                  238
# 247         It_Happened_One_Night            1934                  105
# 248        Passion_of_Joan_of_Arc            1928                  114
# 249                       General            1926                   67
#
#                          genre tomato_score  pop_score
# 0                        Drama           91         98
# ...

# %%
#Dataframe avec 82 liens de films qui n'ont pas fonctionné

# %% [markdown]
# # Export pour visualisation sur Power BI

# %%
df_to.to_csv(r'C:\Users\User\Desktop\scrap_BI.csv', index = False)

# %% [markdown]
# # Trouver les "not found" et tester de généraliser les solutions

# %%
#Isoler les not_found
df_found = df_to[df_to['tomato_score'] == "Not found"]
df_found
# Out:
#                                      title year_of_release  \
# 2                              Dark_Knight            2008
# 3                       Godfather:_Part_II            1974
# 4                             12_Angry_Men            1957
# 5    Lord_of_the_Rings:_Return_of_the_King            2003
# 7                         Schindler's_List            1993
# ..                                     ...             ...
# 221     Nausicaä_of_the_Valley_of_the_Wind            1984
# 227           Monty_Python's_Life_of_Brian            1979
# 238                                Ben-Hur            1959
# 245           Mr._Smith_Goes_to_Washington            1939
# 249                                General            1926
#
#      duration_in_minutes                          genre tomato_score  \
# 2                    152           Action, Crime, Drama    Not found
# 3                    202                   Crime, Drama    Not found
# ...

# %%
#Identifier les patern

# %%
df_found.title = df_found.title.apply(lambda x:x.replace("'", ""))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_found.title = df_found.title.apply(lambda x:x.replace("ä", "a"))

# %%
df_found.title = df_found.title.apply(lambda x:x.replace("-", ""))

# %%
df_found.title = df_found.title.apply(lambda x:x.replace(".", ""))

# %%
df_found.title = df_found.title.apply(lambda x:x.replace(":", ""))

# %%
df_found.title = df_found.title.apply(lambda x:x.replace("Dark_Knight", "the_Dark_Knight"))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_found
# Out:
#                                     title year_of_release  \
# 2                             Dark_Knight            2008
# 3                       Godfather_Part_II            1974
# 4                            12_Angry_Men            1957
# 5    Lord_of_the_Rings_Return_of_the_King            2003
# 7                         Schindlers_List            1993
# ..                                    ...             ...
# 221    Nausicaa_of_the_Valley_of_the_Wind            1984
# 227           Monty_Pythons_Life_of_Brian            1979
# 238                                BenHur            1959
# 245           Mr_Smith_Goes_to_Washington            1939
# 249                               General            1926
#
#      duration_in_minutes                          genre tomato_score  \
# 2                    152           Action, Crime, Drama    Not found
# 3                    202                   Crime, Drama    Not found
# ...

# %%
uri = 'https://www.rottentomatoes.com/m/'
urilist = []
for i in df_found["title"]:
    response = (f'{uri}{str(i)}')  
    urilist.append(response)

# %%
scores_data=[]

# Boucler sur les urls définies plus haut
for url in urilist:
    # récupérer le html de la page
    pag = requests.get(url)
    
    if pag.status_code == 200:
            
    # ajouter les données de la page html à BeautifulSoup   
        soup1 = BeautifulSoup(pag.content, "html.parser")
   
        audience = soup1.find("score-board")["audiencescore"]
    
        scores_data.append(audience)
        
    else: 
        audience = "Not found"
        
        scores_data.append(audience)
        
scores_data
# Out:
# ['Not found',
#  '97',
#  'Not found',
#  'Not found',
#  '97',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '96',
#  'Not found',
#  'Not found',
#  'Not found',
#  '97',
#  'Not found',
#  '95',
#  'Not found',
#  'Not found',
#  '94',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '90',
#  '91',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '89',
#  'Not found',
#  '95',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '91',
#  '93',
#  'Not found',
#  '94',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '95',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '86',
#  'Not found',
#  '89',
#  '84',
# ...

# %%
df_scores_pop = pd.DataFrame(scores_data, columns=['pop_score'])
df_scores_pop
# Out:
#     pop_score
# 0   Not found
# 1          97
# 2   Not found
# 3   Not found
# 4          97
# ..        ...
# 77         74
# 78         93
# 79         89
# 80         94
# 81  Not found
#
# [82 rows x 1 columns]

# %%
df_scores_pop["pop_score"].value_counts()
# Out:
# Not found    60
# 95            3
# 89            3
# 97            3
# 94            3
# 93            2
# 91            2
# 86            1
# 81            1
# 84            1
# 96            1
# 74            1
# 90            1
# Name: pop_score, dtype: int64

# %% [markdown]
# # Application des modifications au dataframe de départ

# %%
data2
# Out:
#                             title year_of_release  duration_in_minutes  \
# 0            Shawshank_Redemption            1994                  142
# 1                       Godfather            1972                  175
# 2                     Dark_Knight            2008                  152
# 3              Godfather:_Part_II            1974                  202
# 4                    12_Angry_Men            1957                   96
# ..                            ...             ...                  ...
# 245  Mr._Smith_Goes_to_Washington            1939                  129
# 246            Gone_with_the_Wind            1939                  238
# 247         It_Happened_One_Night            1934                  105
# 248        Passion_of_Joan_of_Arc            1928                  114
# 249                       General            1926                   67
#
#                          genre
# 0                        Drama
# 1                 Crime, Drama
# ...

# %%
#Copy du dataframe 
df_found = data2.copy()

# %%
df_found.head()
# Out:
#                   title year_of_release  duration_in_minutes  \
# 0  Shawshank_Redemption            1994                  142
# 1             Godfather            1972                  175
# 2           Dark_Knight            2008                  152
# 3    Godfather:_Part_II            1974                  202
# 4          12_Angry_Men            1957                   96
#
#                   genre
# 0                 Drama
# 1          Crime, Drama
# 2  Action, Crime, Drama
# 3          Crime, Drama
# 4          Crime, Drama

# %%
#Modifications deja éffectuées
# data2.title = data2.title.apply(lambda x:x.replace(" ", "_"))
# data2.title = data2.title.apply(lambda x:x.replace("The_", ""))

# %%
#Modifications généralisables sur l'ensemble des not_found
df_found.title = df_found.title.apply(lambda x:x.replace("ä", "a"))
df_found.title = df_found.title.apply(lambda x:x.replace("-", ""))
df_found.title = df_found.title.apply(lambda x:x.replace(".", ""))
df_found.title = df_found.title.apply(lambda x:x.replace(":", ""))
df_found.title = df_found.title.apply(lambda x:x.replace("'", ""))
df_found.title = df_found.title.apply(lambda x:x.replace(",", ""))
#Quelques modifications à la main 
df_found.title = df_found.title.apply(lambda x:x.replace("Dark_Knight", "the_Dark_Knight"))
df_found.title = df_found.title.apply(lambda x:x.replace("Lord_of_the_Rings_Fellowship_of_the_Ring", "the_lord_of_the_rings_the_fellowship_of_the_ring"))
df_found.title = df_found.title.apply(lambda x:x.replace("In_the_Mood_for_Love", "in_the_mood_for_love_2001"))
df_found.title = df_found.title.apply(lambda x:x.replace("Lord_of_the_Rings_Return_of_the_King", "the_lord_of_the_rings_the_return_of_the_king"))

# %%
#Création d'une liste avec les differents liens pour nos films
uri = 'https://www.rottentomatoes.com/m/'
urilist = []
for i in df_found["title"]:
    response = (f'{uri}{str(i)}')  
    urilist.append(response)

# %%
#Récupération du pop_corn Score 
scores_data=[]

# Boucler sur les urls définies plus haut
for url in urilist:
    # récupérer le html de la page
    pag = requests.get(url)
    #Vérifier si la page internet existe
    if pag.status_code == 200:
            
    # ajouter les données de la page html à BeautifulSoup   
        soup1 = BeautifulSoup(pag.content, "html.parser")
   
        audience = soup1.find("score-board")["audiencescore"]
    
        scores_data.append(audience)
        
    else: 
        audience = "Not found"
        
        scores_data.append(audience)
        
scores_data
# Out:
# ['98',
#  '98',
#  '94',
#  '97',
#  'Not found',
#  '86',
#  '96',
#  '97',
#  '91',
#  '96',
#  '95',
#  '95',
#  '97',
#  'Not found',
#  '85',
#  '97',
#  'Not found',
#  '96',
#  '',
#  '86',
#  '97',
#  '96',
#  '95',
#  '94',
#  'Not found',
#  'Not found',
#  '95',
#  'Not found',
#  '97',
#  'Not found',
#  '95',
#  'Not found',
#  '93',
#  '92',
#  '94',
#  '96',
#  '87',
#  '96',
#  '96',
#  'Not found',
#  '93',
#  '94',
#  '97',
#  '95',
#  '94',
#  '95',
#  '95',
#  '94',
#  '95',
#  'Not found',
#  '95',
#  '96',
#  'Not found',
#  '93',
#  '',
#  'Not found',
#  '94',
#  'Not found',
#  '90',
#  '91',
#  '',
#  '91',
#  '90',
#  '93',
#  '96',
#  'Not found',
#  'Not found',
#  '94',
#  '94',
#  'Not found',
#  '96',
#  '93',
#  '94',
#  '94',
#  '95',
#  'Not found',
#  '95',
#  '95',
#  'Not found',
#  '95',
#  'Not found',
#  '20',
#  'Not found',
#  '92',
#  '',
#  '88',
#  '94',
#  'Not found',
#  '93',
#  '93',
#  '93',
#  '94',
#  '96',
#  '92',
# ...

# %%
#Conversion de la liste en Df
df_scores_pop = pd.DataFrame(scores_data, columns=['pop_score'])
df_scores_pop
# Out:
#      pop_score
# 0           98
# 1           98
# 2           94
# 3           97
# 4    Not found
# ..         ...
# 245         94
# 246         92
# 247         93
# 248         93
# 249  Not found
#
# [250 rows x 1 columns]

# %%
df_scores_pop["pop_score"].value_counts()
# Out:
# Not found    50
# 93           39
# 94           35
# 95           28
# 92           13
# 96           13
# 90           12
#              12
# 91           10
# 97            8
# 89            7
# 86            7
# 98            3
# 87            3
# 20            1
# 42            1
# 85            1
# 36            1
# 81            1
# 84            1
# 74            1
# 39            1
# 88            1
# 75            1
# Name: pop_score, dtype: int64

# %%
#les "not found" sont passés de 82 à 50 grace à nos dernières modifications effectuées

# %%
#Récupération du tomato score 
tomato_data=[]

# Boucler sur les urls définies plus haut
for url in urilist:
    # récupérer le html de la page
    pag = requests.get(url)
    
    if pag.status_code == 200:
            
    # ajouter les données de la page html à BeautifulSoup   
        soup1 = BeautifulSoup(pag.content, "html.parser")
   
        audience = soup1.find("score-board")["tomatometerscore"]
    
        tomato_data.append(audience)
        
    else: 
        audience = "Not found"
        
        tomato_data.append(audience)

    
tomato_data
# Out:
# ['91',
#  '97',
#  '94',
#  '96',
#  'Not found',
#  '93',
#  '92',
#  '98',
#  '87',
#  '79',
#  '91',
#  '71',
#  '97',
#  'Not found',
#  '88',
#  '96',
#  'Not found',
#  '94',
#  '',
#  '72',
#  '91',
#  '97',
#  '93',
#  '78',
#  'Not found',
#  'Not found',
#  '96',
#  'Not found',
#  '100',
#  'Not found',
#  '94',
#  'Not found',
#  '75',
#  '76',
#  '90',
#  '95',
#  '77',
#  '83',
#  '88',
#  'Not found',
#  '93',
#  '93',
#  '90',
#  '100',
#  '96',
#  '95',
#  '96',
#  '97',
#  '98',
#  'Not found',
#  '98',
#  '98',
#  'Not found',
#  '90',
#  '',
#  'Not found',
#  '88',
#  'Not found',
#  '94',
#  '85',
#  '',
#  '87',
#  '87',
#  '100',
#  '91',
#  'Not found',
#  'Not found',
#  '81',
#  '93',
#  'Not found',
#  '95',
#  '84',
#  '98',
#  '98',
#  '95',
#  'Not found',
#  '100',
#  '95',
#  'Not found',
#  '93',
#  'Not found',
#  '',
#  'Not found',
#  '92',
#  '',
#  '89',
#  '92',
#  'Not found',
#  '74',
#  '79',
#  '87',
#  '98',
#  '83',
#  '100',
# ...

# %%
#Reconversion en df
df_scores_tomato = pd.DataFrame(tomato_data, columns=['tomato_score'])
df_scores_tomato
# Out:
#     tomato_score
# 0             91
# 1             97
# 2             94
# 3             96
# 4      Not found
# ..           ...
# 245           96
# 246           90
# 247           99
# 248           98
# 249    Not found
#
# [250 rows x 1 columns]

# %%
#Merge du l'index
df_in = df_found.merge(df_scores_tomato, how='inner', left_index=True, right_index=True)
df_clean = df_in.merge(df_scores_pop, how='inner', left_index=True, right_index=True)

# %%
df_clean
# Out:
#                            title year_of_release  duration_in_minutes  \
# 0           Shawshank_Redemption            1994                  142
# 1                      Godfather            1972                  175
# 2                the_Dark_Knight            2008                  152
# 3              Godfather_Part_II            1974                  202
# 4                   12_Angry_Men            1957                   96
# ..                           ...             ...                  ...
# 245  Mr_Smith_Goes_to_Washington            1939                  129
# 246           Gone_with_the_Wind            1939                  238
# 247        It_Happened_One_Night            1934                  105
# 248       Passion_of_Joan_of_Arc            1928                  114
# 249                      General            1926                   67
#
#                          genre tomato_score  pop_score
# 0                        Drama           91         98
# ...

# %%
#Isoler les not_found
df_not = df_clean[df_clean['pop_score'] == "Not found"]
df_not.shape
# Out:
# (50, 6)

# %%
#Isoler les not_found
df_not = df_clean[df_clean['tomato_score'] == "Not found"]
df_not.shape
# Out:
# (50, 6)

# %%
# On obtient donc un dataframe avec seulement 50 "not found" sur 250 films, soit 80% des films pour qui  nous avons pu récupérer 
# les scores

# %%
#Conversion CSV pour visualiser sur powerBI
df_clean.to_csv(r'C:\Users\User\Desktop\df_clean_BI.csv', index = False)

# %%
#Isoler les not_found
df_clean[df_clean['tomato_score'] == "Not found"]
# Out:
#                                                  title year_of_release  \
# 4                                         12_Angry_Men            1957
# 13                        Lord_of_the_Rings_Two_Towers            2002
# 16            Star_Wars_Episode_V__Empire_Strikes_Back            1980
# 24                                   Life_Is_Beautiful            1997
# 25                                               Se7en            1995
# 27                    Star_Wars_Episode_IV__A_New_Hope            1977
# 29                                       Seven_Samurai            1954
# 31                                            Whiplash            2014
# 39                                   Léon_Professional            1994
# 49                                          Casablanca            1942
# 52                                            Hamilton            2020
# 55                                           Your_Name            2016
# ...

# %%
star_wars_episode_vi_return_of_the_jedi

Star_Wars_Episode_VI_Return_of_the_Jedi

neon_genesis_evangelion_the_end_of_evangelion
